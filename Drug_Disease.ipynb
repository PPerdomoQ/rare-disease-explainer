# %% [markdown]
# ## **Import**

# %%
import re
import numpy as np
import pandas as pd
from google.colab import files
import urllib.parse
import urllib.request

# %% [markdown]
# ## **Drug-Target Information**

# %% [markdown]
# ### **Load Files**

# %% [markdown]
# Load the information from Drug Central and Monarch:

# %%
df = pd.read_csv('drug.target.interaction.tsv', header=0, index_col=0)
#nodes = pd.read_csv('graph_nodes_v2022-01-11.csv', header=0)
nodes = pd.read_csv('monarch_nodes_v2022-05-19.csv', header=0)

# %% [markdown]
# ### **Uniprot to Monarch IDs**

# %% [markdown]
# Use Uniprot API to obtain new target IDs:

# %%
url = 'https://www.uniprot.org/uploadlists/'

for i in range(0, df.shape[0]): 

  while True: 

    print('Going through row', i)

    id = df['ACCESSION'][i].split('|')[0]
    org = df['ORGANISM'][i]

    if org == 'Homo sapiens': 
      to = 'HGNC_ID'
      pre = ''
    elif org == 'Rattus norvegicus': 
      to = 'RGD_ID'
      pre = 'RGD:'
    elif org == 'Mus musculus': 
      to = 'MGI_ID'
      pre = ''
    elif org == 'Drosophila melanogaster':
      to = 'FLYBASE_ID'
      pre = 'FlyBase:'
    elif org == 'Caenorhabditis elegans': 
      to = 'WORMBASE_ID'
      pre = 'WormBase:'
    elif org == 'Danio rerio': 
      to = 'ZFIN_ID'
      pre = 'ZFIN:'
    elif org == 'Saccharomyces cerevisiae': 
      to = 'SGD_ID'
      pre = 'SGD:'
    else:   
      to = 'ENSEMBL_ID'
      pre = 'ENSEMBL:'

    params = {
      'from': 'ACC+ID',
      'to': to,
      'format': 'tab',
      'query': id
      }

    data = urllib.parse.urlencode(params)
    data = data.encode('utf-8')
    req = urllib.request.Request(url, data)
    try: 
      with urllib.request.urlopen(req) as f:
        response = f.read()
    except: 
      continue
    try: 
      new_id = response.decode('utf-8').split()[3]
    except: 
      pre = ''
      new_id = 'NA'
    print(pre + new_id)
    df['NEW_ID'][i] = pre + new_id
    break

# %% [markdown]
# Drop rows that don't have a new ID:

# %%
df = df.drop(df[df.NEW_ID == 'NA'].index)

# %% [markdown]
# Keep only rows whose the target is in the Monarch nodes:

# %%
df = df[df['NEW_ID'].isin(list(nodes['id']))]

# %% [markdown]
# Save the Drug-Target dataframe as .csv:

# %%
df.to_csv('drug.target.final.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Create and save a dataframe containing the drug nodes:

# %%
df_drugs = df[['DRUG_NAME', 'STRUCT_ID']]
df_drugs = df_drugs.drop_duplicates()
df_drugs.to_csv('drug_nodes_v2.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ## **Drug-Disease Information**

# %% [markdown]
# ### **Text to CSV**

# %% [markdown]
# Create a Dataframe that will contain the Drug-Disease information:

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %% [markdown]
# Read the .txt file downloaded from TTD and convert it into a pandas dataframe:

# %%
with open('drug_to_disease.txt') as f:
  lines = f.readlines()

# %%
i = 0
id = ''
name = ''
disease = ''
phase = ''

for line in lines: 
  if line.startswith('DRUGNAME'): 
    result = re.search('\t(.*)\n', line)
    name = result.group(1)
  elif line.startswith('TTDDRUID'): 
    result = re.search('\t(.*)\n', line)
    id = result.group(1)
  elif line.startswith('INDICATI'): 
    result = re.search('\t(.*)\[', line)
    result2 = re.search('\](.*)', line)
    disease = result.group(1) 
    phase = result2.group(1) 
    df.loc[i] = [id,name,disease, phase]
    i += 1
  elif line.startswith('\n'): 
    id = ''
    name = ''
    disease = ''
    phase = ''

# %%
df
# Out:
#       DRUG_ID  ...                     PHASE
# 0      D00ABE  ...                   Phase 2
# 1      D00ABE  ...                   Phase 2
# 2      D00ABO  ...                   Phase 1
# 3      D00ABW  ...   Discontinued in Phase 1
# 4      D00ACC  ...   Discontinued in Phase 1
# ...       ...  ...                       ...
# 28973  DZTX12  ...                   Phase 2
# 28974  DZU72C  ...                   Phase 1
# 28975  DZVF15  ...            Clinical Trial
# 28976  DZW53X  ...                   Phase 2
# 28977  DZY4R2  ...                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('drug_to_disease.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Load CSVs**

# %% [markdown]
# Load the drug nodes (obtained from Drug Central) and the Monarch nodes:

# %%
graph_drugs = pd.read_csv('drug_nodes_v2.csv', header=0)
nodes = pd.read_csv('monarch_nodes_v2022-05-19.csv', header=0)

# %% [markdown]
# Get list of unique drugs and diseases:

# %%
graph_diseases = nodes[nodes['semantic_groups'] == 'DISO']
unique_diseases = graph_diseases['name'].unique()
unique_dis_id = graph_diseases['id'].unique()
unique_diseases = [x.lower() for x in unique_diseases]
# Out:
# 25636

# %%
unique_drugs = graph_drugs['DRUG_NAME'].unique()
unique_drugs = [x.lower() for x in unique_drugs]
len(unique_drugs)
# Out:
# 1556

# %% [markdown]
# At this point you should use SORTA tool (https://sorta.molgeniscloud.org/menu/main/sorta?) to match the IDs of TTD to Human Phenotype Ontology (HPO). The file is also available in the project's Github:

# %%
matched = pd.read_csv('matched.csv', header = 0, delimiter = ';')

# %%
matched
# Out:
#                                                    Name  \
# 0                                   respiratory failure
# 1                                    sexual dysfunction
# 2                                        achondroplasia
# 3                                  glabellar frown line
# 4                           testicular germ cell tumour
# ...                                                 ...
# 1796                              systemic mastocytosis
# 1797                    acute iron or aluminum toxicity
# 1798  chronic inflammatory demyelinating polyneuropathy
# 1799                                    aortic aneurysm
# 1800                                              fever
#
#                           ontologyTermName  \
# 0                      Respiratory failure
# 1                  Male sexual dysfunction
# 2                         Bronchodysplasia
# 3                       Prominent glabella
# 4                      Testicular neoplasm
# ...                                    ...
# 1796                          Mastocytosis
# 1797  Abnormal total iron binding capacity
# 1798    Acute demyelinating polyneuropathy
# 1799                       Aortic aneurysm
# 1800                                 Fever
#
#                                 ontologyTermIRI   score  validated  review
# 0     http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1     http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 2     http://purl.obolibrary.org/obo/HP_0006533   62.50      False   False
# 3     http://purl.obolibrary.org/obo/HP_0002057   59.46      False   False
# 4     http://purl.obolibrary.org/obo/HP_0010788   71.11      False   False
# ...                                         ...     ...        ...     ...
# 1796  http://purl.obolibrary.org/obo/HP_0100495   77.42      False   False
# 1797  http://purl.obolibrary.org/obo/HP_0033212   48.15      False   False
# 1798  http://purl.obolibrary.org/obo/HP_0007131   64.86      False   False
# 1799  http://purl.obolibrary.org/obo/HP_0004942  100.00      False   False
# 1800  http://purl.obolibrary.org/obo/HP_0001945  100.00      False   False
#
# [1801 rows x 6 columns]

# %% [markdown]
# Select only those IDs with a score greater than 80:

# %%
matched = matched[matched['score'] > 80]

# %% [markdown]
# Create the final ID:

# %%
matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]

# %%
new_id = []
for i in matched['ID']: 
  id = re.sub("[^0-9a-zA-Z]+", ":", i)
  new_id.append(id)
matched['ID'] = new_id

# %%
i = 0
for index, row in df.iterrows(): 
  if row['DRUG_NAME'].lower() in unique_drugs: 
    if row['DISEASES'].lower() in unique_diseases: 
      i += 1
# Out:
# 0

# %% [markdown]
# ### **Merging**

# %%
modified = []
for d in df['DISEASES']: 
  new_string = re.sub("[^0-9a-zA-Z]+", " ", d)
  modified.append(new_string.lower())

# %%
df['Name'] = modified

# %%
df['Name'] = df['Name'].str.strip()
matched['Name'] = matched['Name'].str.strip()

# %%
final = pd.merge(df, matched, on = 'Name', how = 'left')

# %%
final
# Out:
#        Unnamed: 0 DRUG_ID     DRUG_NAME  \
# 0               0  D00ABE       ALD-301
# 1               1  D00ABE       ALD-301
# 2               2  D00ABO       KW-2449
# 3               3  D00ABW      Opterone
# 4               4  D00ACC        ND1251
# ...           ...     ...           ...
# 29562       28974  DZU72C       OKI 179
# 29563       28975  DZVF15       TRN-110
# 29564       28976  DZW53X    GSK4069889
# 29565       28976  DZW53X    GSK4069889
# 29566       28977  DZY4R2  JNJ-74699157
#
#                                         DISEASES                     PHASE  \
# 0                                      Ischemia                    Phase 2
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 3                            Hormone deficiency    Discontinued in Phase 1
# 4                                    Depression    Discontinued in Phase 1
# ...                                          ...                       ...
# 29562                       Solid tumour/cancer                    Phase 1
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
# 29566                       Solid tumour/cancer                    Phase 1
#
#                                            Name  \
# 0                                      ischemia
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 3                            hormone deficiency
# 4                                    depression
# ...                                         ...
# 29562                       solid tumour cancer
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
# 29566                       solid tumour cancer
#
#                                         ontologyTermName  \
# 0                                      Cerebral ischemia
# 1                           Peripheral arterial stenosis
# 2                                 Acute myeloid leukemia
# 3      Decreased response to growth hormone stimuatio...
# 4                                           Depressivity
# ...                                                  ...
# 29562               Benign gastrointestinal tract tumors
# 29563           Attention deficit hyperactivity disorder
# 29564                      Non-small cell lung carcinoma
# 29565                      Non-small cell lung carcinoma
# 29566               Benign gastrointestinal tract tumors
#
#                                  ontologyTermIRI  score  validated  review  \
# 0      http://purl.obolibrary.org/obo/HP_0002637   75.0      False   False
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0      False   False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0      False   False
# 3      http://purl.obolibrary.org/obo/HP_0000824   80.0      False   False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0      False   False
# ...                                          ...    ...        ...     ...
# 29562  http://purl.obolibrary.org/obo/HP_0006719   60.0      False   False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0      False   False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
# 29566  http://purl.obolibrary.org/obo/HP_0006719   60.0      False   False
#
#                ID
# 0      HP:0002637
# 1      HP:0004950
# 2      HP:0004808
# 3      HP:0000824
# 4      HP:0000716
# ...           ...
# 29562  HP:0006719
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
# 29566  HP:0006719
#
# [29567 rows x 12 columns]

# %%
final.to_csv('drug_to_disease_HP.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Comparison**

# %%
final = pd.read_csv('drug_to_disease_HP.csv', header=0)

# %%
final_filtered = final[final['score'] == 100]

# %%
len(final_filtered)
# Out:
# 12151

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID                                        DRUG_NAME  \
# 1               1  D00ABE                                          ALD-301
# 2               2  D00ABO                                          KW-2449
# 4               4  D00ACC                                           ND1251
# 11             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# 12             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# ...           ...     ...                                              ...
# 29556       28968  DZNH43                                          MT-3724
# 29561       28973  DZTX12                                           ASC-J9
# 29563       28975  DZVF15                                          TRN-110
# 29564       28976  DZW53X                                       GSK4069889
# 29565       28976  DZW53X                                       GSK4069889
#
#                                         DISEASES                     PHASE  \
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 4                                    Depression    Discontinued in Phase 1
# 11                   Non-small-cell lung cancer                    Phase 2
# 12                   Non-small-cell lung cancer                    Phase 2
# ...                                          ...                       ...
# 29556                           B-cell lymphoma                    Phase 1
# 29561                   End-stage renal disease                    Phase 2
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
#
#                                            Name  \
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 4                                    depression
# 11                   non small cell lung cancer
# 12                   non small cell lung cancer
# ...                                         ...
# 29556                           b cell lymphoma
# 29561                   end stage renal disease
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
#
#                                ontologyTermName  \
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 4                                  Depressivity
# 11                Non-small cell lung carcinoma
# 12                Non-small cell lung carcinoma
# ...                                         ...
# 29556                           B-cell lymphoma
# 29561            Stage 5 chronic kidney disease
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
#
#                                  ontologyTermIRI  score  validated  review  \
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0      False   False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0      False   False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0      False   False
# 11     http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
# 12     http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
# ...                                          ...    ...        ...     ...
# 29556  http://purl.obolibrary.org/obo/HP_0012191  100.0      False   False
# 29561  http://purl.obolibrary.org/obo/HP_0003774  100.0      False   False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0      False   False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0      False   False
#
#                ID
# 1      HP:0004950
# 2      HP:0004808
# 4      HP:0000716
# 11     HP:0030358
# 12     HP:0030358
# ...           ...
# 29556  HP:0012191
# 29561  HP:0003774
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
#
# [12151 rows x 12 columns]

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %%
unique_drugs
# Out:
# ['levobupivacaine',
#  '(s)-nicardipine',
#  '(s)-nitrendipine',
#  'levdobutamine',
#  'aminopterin',
#  'phenylbutanoic acid',
#  'azacitidine',
#  'methoxsalen',
#  'acamprosate',
#  'acarbose',
#  'acebutolol',
#  'aceclofenac',
#  'paracetamol',
#  'acetohexamide',
#  'acetophenazine',
#  'racecadotril',
#  'acetylcholine',
#  'acetylcysteine',
#  'acetyldigitoxin',
#  'acepromazine',
#  'acyclovir',
#  'adapalene',
#  'adefovir dipivoxil',
#  'adenine',
#  'adenosine',
#  'adenosine triphosphate',
#  'adenosine phosphate',
#  'adiphenine',
#  'ajmaline',
#  'alacepril',
#  'salbutamol',
#  'alcuronium',
#  'alfentanil',
#  'aliskiren',
#  'alizapride',
#  'allopurinol',
#  'alosetron',
#  'alfacalcidol',
#  'alfaxalone',
#  'alprazolam',
#  'alprenolol',
#  'alprostadil',
#  'alvimopan',
#  'amantadine',
#  'ambroxol',
#  'amcinonide',
#  'amifostine',
#  'amiloride',
#  'amineptine',
#  'aminoglutethimide',
#  'aminoquinuride',
#  'amiodarone',
#  'amisulpride',
#  'amitriptyline',
#  'amitriptylinoxide',
#  'amlexanox',
#  'amlodipine',
#  'amodiaquine',
#  'amoxapine',
#  'amperozide',
#  'amfetamine',
#  'ampicillin',
#  'amprenavir',
#  'amrinone',
#  'amsacrine',
#  'anastrozole',
#  'androisoxazole',
#  'androstenediol',
#  'androstenedione',
#  'anileridine',
#  'octatropine methylbromide',
#  'dithranol',
#  'apomorphine',
#  'aprepitant',
#  'aprindine',
#  'aranidipine',
#  'arbutamine',
#  'argatroban',
#  'aripiprazole',
#  'arsenic trioxide',
#  'astemizole',
#  'atazanavir',
#  'atenolol',
#  'atomoxetine',
#  'atorvastatin',
#  'atovaquone',
#  'atracurium',
#  'atropine',
#  'azathioprine',
#  'azelastine',
#  'azelnidipine',
#  'azimilide',
#  'azithromycin',
#  'baclofen',
#  'balsalazide',
#  'bambuterol',
#  'barnidipine',
#  'beclometasone dipropionate',
#  'benazepril',
#  'bendamustine',
#  'bendroflumethiazide',
#  'benperidol',
#  'diphenidol',
#  'benserazide',
#  'benzarone',
#  'benzbromarone',
#  'benziodarone',
#  'benzocaine',
#  'benzonatate',
#  'benzphetamine',
#  'benzquinamide',
#  'benzthiazide',
#  'benzatropine',
#  'benzyl benzoate',
#  'bepridil',
#  'beraprost',
#  'betamethasone',
#  'betamethasone acetate',
#  'betamethasone benzoate',
#  'betamethasone dipropionate',
#  'betamethasone valerate',
#  'betaxolol',
#  'bethanechol',
#  'bevantolol',
#  'bexarotene',
#  'bezafibrate',
#  'bicalutamide',
#  'bifonazole',
#  'biperiden',
#  'bisacodyl',
#  'bisoprolol',
#  'bivalirudin',
#  'blonanserin',
#  'bopindolol',
#  'bortezomib',
#  'bosentan',
#  'bretylium',
#  'brodimoprim',
#  'bromhexine',
#  'bromocriptine',
#  'bromopride',
#  'bromperidol',
#  'brompheniramine',
#  'budesonide',
#  'budipine',
#  'buflomedil',
#  'bufuralol',
#  'bumetanide',
#  'levobunolol',
#  'bupivacaine',
#  'bupranolol',
#  'buprenorphine',
#  'bupropion',
#  'buspirone',
#  'butenafine',
#  'butorphanol',
#  'butriptyline',
#  'scopolamine butylbromide',
#  'cabergoline',
#  'cadralazine',
#  'caffeine',
#  'calcifediol',
#  'calcipotriene',
#  'calcitriol',
#  'camphor',
#  'camostat',
#  'candesartan cilexetil',
#  'captopril',
#  'caramiphen',
#  'carazolol',
#  'carbachol',
#  'carbamazepine',
#  'carbenicillin',
#  'pentoxyverine',
#  'carbidopa',
#  'carbutamide',
#  'carmofur',
#  'levocarnitine',
#  'carperitide',
#  'carfenazine',
#  'carpipramine',
#  'carteolol',
#  'carvedilol',
#  'cefixime',
#  'cefotetan',
#  'cefsulodin',
#  'ceftriaxone',
#  'celecoxib',
#  'celiprolol',
#  'cefapirin',
#  'cetirizine',
#  'cevimeline',
#  'chlorambucil',
#  'chloramphenicol',
#  'chlordiazepoxide',
#  'chlormadinone',
#  'chloroprocaine',
#  'chloropyramine',
#  'chloroquine',
#  'chlorothiazide',
#  'chlorphenamine',
#  'chlorphentermine',
#  'chlorproethazine',
#  'chlorpromazine',
#  'chlorpropamide',
#  'chlorprothixene',
#  'chlortetracycline',
#  'chlortalidone',
#  'chlorzoxazone',
#  'cianidanol',
#  'cibenzoline',
#  'cicaprost',
#  'ciclesonide',
#  'cicloprolol',
#  'cilazapril',
#  'cilnidipine',
#  'cinacalcet',
#  'cinnarizine',
#  'ciprofibrate',
#  'cisapride',
#  'cisatracurium',
#  'citalopram',
#  'citric acid',
#  'cladribine',
#  'clarithromycin',
#  'clebopride',
#  'clemastine',
#  'clenbuterol',
#  'clevidipine',
#  'clidinium',
#  'clioquinol',
#  'clodronic acid',
#  'clofarabine',
#  'clofibrate',
#  'clofibric acid',
#  'clomifene',
#  'clomipramine',
#  'clonidine',
#  'clonixin',
#  'clopidogrel',
#  'clorazepate',
#  'clorprenaline',
#  'clotiapine',
#  'clotrimazole',
#  'clozapine',
#  'cocaine',
#  'codeine',
#  'colchicine',
#  'colforsin daropate',
#  'cortisone acetate',
#  'cortivazol',
#  'coumarin',
#  'cyamemazine',
#  'cyclizine',
#  'cyclobenzaprine',
#  'cycloguanil',
#  'cyclopentolate',
#  'cyclophosphamide',
#  'cycloserine',
#  'ciclosporin',
#  'cyclothiazide',
#  'cycrimine',
#  'cyproheptadine',
#  'cyproterone acetate',
#  'cytarabine',
#  'dactinomycin',
#  'dabigatran etexilate',
#  'danazol',
#  'dantrolene',
#  'dapsone',
#  'darifenacin',
#  'dasatinib',
#  'daunorubicin',
#  'deanol',
#  'debrisoquine',
#  'decamethonium',
#  'decitabine',
#  'deferoxamine',
#  'delapril',
#  'denopamine',
#  'deserpidine',
#  'desflurane',
#  'desipramine',
#  'deslanoside',
#  'desloratadine',
#  'nordazepam',
#  'desoximetasone',
#  'desoxycortone',
#  'dexamethasone',
#  'dexamethasone acetate',
#  'dexamethasone palmitate',
#  'dexamethasone valerate',
#  'dexetimide',
#  'dexfenfluramine',
#  'dexmethylphenidate',
#  'dexniguldipine',
#  'dexamfetamine',
#  'dextromethorphan',
#  'dextropropoxyphene',
#  'dextrothyroxine',
#  'dezocine',
#  'diacerein',
#  'diazepam',
#  'diazoxide',
#  'cinchocaine',
#  'phenazone',
#  'dichloroacetic acid',
#  'diclofenac',
#  'dicloxacillin',
#  'dicoumarol',
#  'dicycloverine',
#  'diethylpropion',
#  'diethylstilbestrol',
#  'difenoxin',
#  'diflunisal',
#  'digitoxin',
#  'digoxin',
#  'alpha-ergocryptine',
#  'dihydrocodeine',
#  'dihydroergocristine',
#  'dihydroergotamine',
#  'hydroquinidine',
#  'dilazep',
#  'dilevalol',
#  'diltiazem',
#  'dimemorfan',
#  'dimenhydrinate',
#  'dimetindene',
#  'dimethyltubocurarinium',
#  'dinoprost',
#  'dinoprostone',
#  'diphemanil',
#  'diphenhydramine',
#  'diphenoxylate',
#  'diphenylpyraline',
#  'diprafenone',
#  'dipyridamole',
#  'disopyramide',
#  'disulfiram',
#  'ditiocarb',
#  'levomenthol',
#  'dobutamine',
#  'docetaxel',
#  'dofetilide',
#  'domperidone',
#  'donepezil',
#  'dopamine',
#  'dosulepin',
#  'doxapram',
#  'doxazosin',
#  'doxepin',
#  'doxercalciferol',
#  'doxorubicin',
#  'doxycycline',
#  'drostanolone propionate',
#  'droperidol',
#  'drospirenone',
#  'drotaverine',
#  'droxidopa',
#  'duloxetine',
#  'dyclonine',
#  'diprophylline',
#  'ebastine',
#  'econazole',
#  'edatrexate',
#  'edetic acid',
#  'efavirenz',
#  'eflornithine',
#  'efonidipine',
#  'elliptinium',
#  'enalapril',
#  'enalaprilat',
#  'encainide',
#  'endralazine',
#  'enflurane',
#  'enoxacin',
#  'enoximone',
#  'enprofylline',
#  'enprostil',
#  'entacapone',
#  'epalrestat',
#  'eperisone',
#  'epinastine',
#  'epinephrine',
#  'eplerenone',
#  'epoprostenol',
#  'eprosartan',
#  'ergometrine',
#  'ergotamine',
#  'erlotinib',
#  'erythromycin',
#  'escitalopram',
#  'esmolol',
#  'estazolam',
#  'estradiol',
#  'estradiol benzoate',
#  'estramustine phosphate',
#  'estriol succinate',
#  'eszopiclone',
#  'ethacrynic acid',
#  'ethambutol',
#  'ethinylestradiol',
#  'ethisterone',
#  'profenamine',
#  'ethosuximide',
#  'ethotoin',
#  'ethylestrenol',
#  'etynodiol',
#  'etidocaine',
#  'etilamfetamine',
#  'etilefrine',
#  'etizolam',
#  'etomidate',
#  'etoperidone',
#  'etoposide',
#  'etryptamine',
#  'everolimus',
#  'exemestane',
#  'fadrozole',
#  'fasudil',
#  'febuxostat',
#  'felbamate',
#  'felodipine',
#  'fendiline',
#  'fenfluramine',
#  'fenofibrate',
#  'fenoldopam',
#  'fentanyl',
#  'fexofenadine',
#  'flavoxate',
#  'flecainide',
#  'floxacillin',
#  'fluconazole',
#  'fludarabine phosphate',
#  'fludrocortisone acetate',
#  'flufenamic acid',
#  'flumazenil',
#  'flumetasone pivalate',
#  'flunarizine',
#  'flunisolide',
#  'flunitrazepam',
#  'fluocinolone acetonide',
#  'fluocinonide',
#  'fluorometholone',
#  'fluoxetine',
#  'fluoxymesterone',
#  'flupentixol',
#  'fluphenazine',
#  'fluphenazine decanoate',
#  'fluphenazine enanthate',
#  'flupirtine',
#  'fluprednisolone',
#  'fludroxycortide',
#  'fluspirilene',
#  'flutamide',
#  'fluticasone propionate',
#  'fluvastatin',
#  'fluvoxamine',
#  'leucovorin',
#  'formestane',
#  'formoterol',
#  'fosinopril',
#  'fosphenytoin',
#  'fulvestrant',
#  'furosemide',
#  'aminobutyric acid',
#  'gabapentin',
#  'galantamine',
#  'gallamine',
#  'gallopamil',
#  'gamolenic acid',
#  'ganciclovir',
#  'gefitinib',
#  'gemcitabine',
#  'gemfibrozil',
#  'gimeracil',
#  'glibornuride',
#  'gliclazide',
#  'glimepiride',
#  'glipizide',
#  'gliquidone',
#  'glisoxepide',
#  'glutamic acid',
#  'glibenclamide',
#  'glycine',
#  'gossypol',
#  'granisetron',
#  'grepafloxacin',
#  'ulobetasol propionate',
#  'halofantrine',
#  'haloperidol',
#  'halopredone acetate',
#  'haloprogin',
#  'halothane',
#  'hesperetin',
#  'hexachlorophene',
#  'hexobarbital',
#  'hexobendine',
#  'hexocyclium',
#  'hexylcaine',
#  'hexylresorcinol',
#  'homatropine',
#  'hycanthone',
#  'hydralazine',
#  'hydrochlorothiazide',
#  'hydrocodone',
#  'hydrocortamate',
#  'hydrocortisone',
#  'hydrocortisone cypionate',
#  'hydroflumethiazide',
#  'hydromorphone',
#  'hydroxychloroquine',
#  'hydroxyzine',
#  'hyoscyamine',
#  'ibudilast',
#  'ibuprofen',
#  'ibutilide',
#  'idebenone',
#  'ifenprodil',
#  'iloprost',
#  'imatinib',
#  'imidapril',
#  'imipramine',
#  'imiquimod',
#  'indalpine',
#  'indapamide',
#  'indecainide',
#  'indenolol',
#  'indinavir',
#  'indomethacin',
#  'diiodohydroxyquinoline',
#  'ipratropium',
#  'iprindole',
#  'iproniazid',
#  'irbesartan',
#  'irinotecan',
#  'isocarboxazid',
#  'isoflurane',
#  'fluostigmine',
#  'isoniazid',
#  'isoprenaline',
#  'isopropamide',
#  'isosorbide dinitrate',
#  'isosorbide mononitrate',
#  'isotretinoin',
#  'isradipine',
#  'itraconazole',
#  'ixabepilone',
#  'ketamine',
#  'ketanserin',
#  'ketobemidone',
#  'ketoconazole',
#  'ketorolac',
#  'ketotifen',
#  'labetalol',
#  'lacidipine',
#  'lamotrigine',
#  'landiolol',
#  'lansoprazole',
#  'lapatinib',
#  'aspartic acid',
#  'leflunomide',
#  'letrozole',
#  'levallorphan',
#  'levamisole',
#  'levamfetamine',
#  'levetiracetam',
#  'levodopa',
#  'levofloxacin',
#  'levomethadyl acetate',
#  'levonorgestrel',
#  'levorphanol',
#  'levosimendan',
#  'levosulpiride',
#  'lidocaine',
#  'lidoflazine',
#  'lindane',
#  'linezolid',
#  'liothyronine',
#  'lisinopril',
#  'lisuride',
#  'lofepramine',
#  'lomerizine',
#  'loperamide',
#  'lopinavir',
#  'loprazolam',
#  'loratadine',
#  'lorcainide',
#  'losartan',
#  'loteprednol etabonate',
#  'lovastatin',
#  'loxapine',
#  'lucanthone',
#  'lumefantrine',
#  'lysergide',
#  'manidipine',
#  'maprotiline',
#  'masoprocol',
#  'maxacalcitol',
#  'mazindol',
#  'mebendazole',
#  'mebhydrolin',
#  'mecamylamine',
#  'meclofenamic acid',
#  'medroxalol',
#  'medroxyprogesterone',
#  'medrysone',
#  'mefenamic acid',
#  'mefloquine',
#  'megestrol acetate',
#  'melatonin',
#  'melperone',
#  'memantine',
#  'menadione',
#  'pecazine',
#  'mepenzolate',
#  'pethidine',
#  'mephenytoin',
#  'mepivacaine',
#  'meprednisone',
#  'meprobamate',
#  'meproscillarin',
#  'meptazinol',
#  'mequitazine',
#  'mercaptopurine',
#  'mesalazine',
#  'mesoridazine',
#  'mestranol',
#  'metergoline',
#  'metformin',
#  'methacholine',
#  'methadone',
#  'acetylmethadol',
#  'methamphetamine',
#  'methapyrilene',
#  'methaqualone',
#  'methotrexate',
#  'methscopolamine',
#  'methsuximide',
#  'methylclothiazide',
#  'metildigoxin',
#  'methyldopa',
#  'methylthioninium chloride',
#  'methylergometrine',
#  'naltrexone',
#  'methylphenidate',
#  'methylprednisolone',
#  'methylprednisolone acetate',
#  'methylprednisolone succinate',
#  'methysergide',
#  'metipranolol',
#  'metixene',
#  'metoclopramide',
#  'metolazone',
#  'metopimazine',
#  'metoprolol',
#  'metyrapone',
#  'metirosine',
#  'mexiletine',
#  'mezlocillin',
#  'mianserin',
#  'mibefradil',
#  'miconazole',
#  'midazolam',
#  'mifepristone',
#  'miglitol',
#  'miglustat',
#  'milnacipran',
#  'milrinone',
#  'miltefosine',
#  'mimosine',
#  'minaprine',
#  'minoxidil',
#  'mirtazapine',
#  'misoprostol',
#  'mitiglinide',
#  'mitotane',
#  'mitoxantrone',
#  'mivacurium',
#  'mizolastine',
#  'moclobemide',
#  'modafinil',
#  'moexipril',
#  'molindone',
#  'mometasone furoate',
#  'monobenzone',
#  'montelukast',
#  'moperone',
#  'moracizine',
#  'morphine',
#  'mosapride',
#  'mupirocin',
#  'nabumetone',
#  'nadolol',
#  'nafamostat',
#  'naftifine',
#  'nalbuphine',
#  'nalmefene',
#  'nalorphine',
#  'naloxone',
#  'nandrolone',
#  'nandrolone decanoate',
#  'nandrolone phenpropionate',
#  'naproxen',
#  'nateglinide',
#  'nebivolol',
#  'nefazodone',
#  'nefopam',
#  'nelfinavir',
#  'nemonapride',
#  'framycetin',
#  'neostigmine',
#  'nepinalone',
#  'nesiritide',
#  'nicotinamide',
#  'nicardipine',
#  'niclosamide',
#  'nicorandil',
#  'nicotine',
#  'nifedipine',
#  'nifekalant',
#  'niflumic acid',
#  'nifuroxazide',
#  'nilotinib',
#  'nilutamide',
#  'nilvadipine',
#  'nimesulide',
#  'nimodipine',
#  'nisoldipine',
#  'nitisinone',
#  'nitrendipine',
#  'glyceryl trinitrate',
#  'nomifensine',
#  'norepinephrine',
#  'norethisterone',
#  'norethindrone acetate',
#  'norethynodrel',
#  'norfloxacin',
#  'nortriptyline',
#  'octreotide',
#  'ofloxacin',
#  'olanzapine',
#  'olmesartan medoxomil',
#  'olsalazine',
#  'omapatrilat',
#  'omeprazole',
#  'ondansetron',
#  'opipramol',
#  'orlistat',
#  'orphenadrine',
#  'ouabain',
#  'oxacillin',
#  'oxandrolone',
#  'oxaprozin',
#  'oxatomide',
#  'oxcarbazepine',
#  'oxyphencyclimine',
#  'oxprenolol',
#  'oxybutynin',
#  'oxycodone',
#  'oxymetazoline',
#  'oxymetholone',
#  'oxymorphone',
#  'oxyphenonium',
#  'paclitaxel',
#  'aminosalicylic acid',
#  'pancuronium',
#  'pantoprazole',
#  'papaverine',
#  'paramethadione',
#  'pargyline',
#  'paricalcitol',
#  'paroxetine',
#  'pemetrexed',
#  'pemoline',
#  'penbutolol',
#  'penfluridol',
#  'pentamidine',
#  'pentobarbital',
#  'pentoxifylline',
#  'pergolide',
#  'perhexiline',
#  'periciazine',
#  'perindopril',
#  'perlapine',
#  'perospirone',
#  'perphenazine',
#  'phenacemide',
#  'phenazocine',
#  'phenazopyridine',
#  'phencyclidine',
#  'phendimetrazine',
#  'phenelzine',
#  'phenindione',
#  'pheniprazine',
#  'pheniramine',
#  'phenmetrazine',
#  'phenobarbital',
#  'phenoxybenzamine',
#  'phensuximide',
#  'phentermine',
#  'phentolamine',
#  'phenylalanine',
#  'phenylephrine',
#  'phenylpropanolamine',
#  'phenyltoloxamine',
#  'phenytoin',
#  'physostigmine',
#  'pilocarpine',
#  'pilsicainide',
#  'pimecrolimus',
#  'pimobendan',
#  'pimozide',
#  'pinacidil',
#  'pindolol',
#  'pioglitazone',
#  'pipamazine',
#  'pipamperone',
#  'pipecuronium',
#  'piperazine',
#  'pipotiazine palmitate',
#  'pirenzepine',
#  'piretanide',
#  'piribedil',
#  'pirlindole',
#  'pirmenol',
#  'pitavastatin',
#  'pizotifen',
#  'polythiazide',
#  'pramipexole',
#  'prednicarbate',
#  'prednisolone',
#  'prednisolone acetate',
#  'prednisolone tebutate',
#  'prednisone',
#  'pregabalin',
#  'prenalterol',
#  'prenylamine',
#  'pridinol',
#  'prilocaine',
#  'primaquine',
#  'primidone',
#  'probucol',
#  'procainamide',
#  'procaine',
#  'procaterol',
#  'prochlorperazine',
#  'procyclidine',
#  'progesterone',
#  'promazine',
#  'promegestone',
#  'promethazine',
#  'propafenone',
#  'propantheline',
#  'proparacaine',
#  'propiomazine',
#  'propiram',
#  'propofol',
#  'propranolol',
#  'propyphenazone',
#  'proscillaridin',
#  'protirelin',
#  'protriptyline',
#  'pyrazinamide',
#  'pyridostigmine',
#  'mepyramine',
#  'pyrimethamine',
#  'pyrvinium',
#  'quazepam',
#  'quetiapine',
#  'mepacrine',
#  'quinapril',
#  'quinethazone',
#  'quinidine',
#  'rabeprazole',
#  'raloxifene',
#  'raltitrexed',
#  'ramipril',
#  'ranolazine',
#  'reboxetine',
#  'regadenoson',
#  'remifentanil',
#  'remoxipride',
#  'repaglinide',
#  'rescinnamine',
#  'reserpine',
#  'ribavirin',
#  'riluzole',
#  'rimexolone',
#  'levisoprenaline',
#  'risperidone',
#  'ritonavir',
#  'rivastigmine',
#  'rizatriptan',
#  'rocuronium',
#  'rofecoxib',
#  'ropinirole',
#  'ropivacaine',
#  'rosiglitazone',
#  'rosuvastatin',
#  'rotigotine',
#  'salmeterol',
#  'saquinavir',
#  'scopolamine',
#  'selegiline',
#  'sertindole',
#  'sertraline',
#  'sevoflurane',
#  'sibutramine',
#  'sildenafil',
#  'silymarin',
#  'sirolimus',
#  'sitagliptin',
#  'sitosterol',
#  'solifenacin',
#  'sorafenib',
#  'sorivudine',
#  'sotalol',
#  'sparfloxacin',
#  'spiperone',
#  'spirapril',
#  'spironolactone',
#  'stanozolol',
#  'stiripentol',
#  'strychnine',
#  'succinic acid',
#  'suxamethonium',
#  'sufentanil',
#  'sulconazole',
#  'sulfacetamide',
#  'sulfadiazine',
#  'sulfadimethoxine',
#  'sulfaethidole',
#  'sulfaguanidine',
#  'sulfasalazine',
#  'sulfafurazole',
#  'sulforidazine',
#  'sulindac',
#  'suloctidil',
#  'sulpiride',
#  'sulprostone',
#  'sultopride',
#  'sumatriptan',
#  'sunitinib',
#  'tacrine',
#  'tacrolimus',
#  'tadalafil',
#  'talinolol',
#  'talipexole',
#  'taltirelin',
#  'tamoxifen',
#  'tamsulosin',
#  'tandospirone',
#  'tazarotene',
#  'teicoplanin aglycone',
#  'telithromycin',
#  'telmisartan',
#  'temocapril',
#  'teniposide',
#  'terbinafine',
#  'terconazole',
#  'terfenadine',
#  'terguride',
#  'terodiline',
#  'testolactone',
#  'testosterone',
#  'testosterone undecanoate',
#  'tetrabenazine',
#  'tetracaine',
#  'sapropterin',
#  'thalidomide',
#  'theophylline',
#  'thiabendazole',
#  'thiethylperazine',
#  'thioguanine',
#  'thioproperazine',
#  'thioridazine',
#  'thiothixene',
#  'levothyroxine',
#  'tiagabine',
#  'tianeptine',
#  'tiapride',
#  'tibolone',
#  'ticlopidine',
#  'tilidine',
#  'tiludronic acid',
#  'tioconazole',
#  'tiotropium bromide',
#  'tiquizium',
#  'tocainide',
#  'tofisopam',
#  'tolazamide',
#  'tolbutamide',
#  'tolcapone',
#  'tolfenamic acid',
#  'tolonium',
#  'toloxatone',
#  'tolperisone',
#  'tolterodine',
#  'topiramate',
#  ...]

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  if row['DRUG_NAME'].lower() not in unique_drugs or row['ID'] not in unique_dis_id:
   final_filtered = final_filtered.drop(labels = index, axis = 0)
len(final_filtered)
# Out:
# 599

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  drug = row['DRUG_NAME'].lower()
  id = graph_drugs[graph_drugs['DRUG_NAME'] == drug]['STRUCT_ID'].values[0]
  final_filtered.at[index, 'DRUG_ID'] = id
len(final_filtered)

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID         DRUG_NAME  \
# 58             54     622    Chlorpropamide
# 154           148    4135  Lisdexamfetamine
# 220           213    1275        Gallopamil
# 221           214    1275        Gallopamil
# 355           341    1827         Moexipril
# ...           ...     ...               ...
# 27189       26704  D0Z6UC       Sumatriptan
# 27209       26724  D0Z7KE        Isradipine
# 27445       26953  D0ZS8P      Clomipramine
# 27491       26996  D0ZX1P         FADROZOLE
# 28332       27801  DB82TO         Tofisopam
#
#                                         DISEASES                     PHASE  \
# 58               Non-insulin dependent diabetes                   Approved
# 154    Attention deficit hyperactivity disorder                   Approved
# 220                                      Asthma                    Phase 2
# 221                                Hypertension    Discontinued in Phase 1
# 355                                Hypertension                   Approved
# ...                                          ...                       ...
# 27189                                  Migraine                   Approved
# 27209                              Hypertension                   Approved
# 27445                                Depression                   Approved
# 27491                             Breast cancer                   Approved
# 28332                            Hyperuricaemia                    Phase 2
#
#                                            Name  \
# 58               non insulin dependent diabetes
# 154    attention deficit hyperactivity disorder
# 220                                      asthma
# 221                                hypertension
# 355                                hypertension
# ...                                         ...
# 27189                                  migraine
# 27209                              hypertension
# 27445                                depression
# 27491                             breast cancer
# 28332                            hyperuricaemia
#
#                                ontologyTermName  \
# 58                    Type II diabetes mellitus
# 154    Attention deficit hyperactivity disorder
# 220                                      Asthma
# 221                                Hypertension
# 355                                Hypertension
# ...                                         ...
# 27189                                  Migraine
# 27209                              Hypertension
# 27445                              Depressivity
# 27491                          Breast carcinoma
# 28332                             Hyperuricemia
#
#                                  ontologyTermIRI  score  validated  review  \
# 58     http://purl.obolibrary.org/obo/HP_0005978  100.0      False   False
# 154    http://purl.obolibrary.org/obo/HP_0007018  100.0      False   False
# 220    http://purl.obolibrary.org/obo/HP_0002099  100.0      False   False
# 221    http://purl.obolibrary.org/obo/HP_0000822  100.0      False   False
# 355    http://purl.obolibrary.org/obo/HP_0000822  100.0      False   False
# ...                                          ...    ...        ...     ...
# 27189  http://purl.obolibrary.org/obo/HP_0002076  100.0      False   False
# 27209  http://purl.obolibrary.org/obo/HP_0000822  100.0      False   False
# 27445  http://purl.obolibrary.org/obo/HP_0000716  100.0      False   False
# 27491  http://purl.obolibrary.org/obo/HP_0003002  100.0      False   False
# 28332  http://purl.obolibrary.org/obo/HP_0002149  100.0      False   False
#
#                ID
# 58     HP:0005978
# 154    HP:0007018
# 220    HP:0002099
# 221    HP:0000822
# 355    HP:0000822
# ...           ...
# 27189  HP:0002076
# 27209  HP:0000822
# 27445  HP:0000716
# 27491  HP:0003002
# 28332  HP:0002149
#
# [599 rows x 12 columns]

# %%
final_filtered = final_filtered.drop(labels = ['Unnamed: 0', 'score'], axis =1)

# %%
final_filtered
# Out:
#       DRUG_ID         DRUG_NAME                                   DISEASES  \
# 58        622    Chlorpropamide            Non-insulin dependent diabetes
# 154      4135  Lisdexamfetamine  Attention deficit hyperactivity disorder
# 220      1275        Gallopamil                                    Asthma
# 221      1275        Gallopamil                              Hypertension
# 355      1827         Moexipril                              Hypertension
# ...       ...               ...                                        ...
# 27189  D0Z6UC       Sumatriptan                                  Migraine
# 27209  D0Z7KE        Isradipine                              Hypertension
# 27445  D0ZS8P      Clomipramine                                Depression
# 27491  D0ZX1P         FADROZOLE                             Breast cancer
# 28332  DB82TO         Tofisopam                            Hyperuricaemia
#
#                           PHASE                                      Name  \
# 58                     Approved            non insulin dependent diabetes
# 154                    Approved  attention deficit hyperactivity disorder
# 220                     Phase 2                                    asthma
# 221     Discontinued in Phase 1                              hypertension
# 355                    Approved                              hypertension
# ...                         ...                                       ...
# 27189                  Approved                                  migraine
# 27209                  Approved                              hypertension
# 27445                  Approved                                depression
# 27491                  Approved                             breast cancer
# 28332                   Phase 2                            hyperuricaemia
#
#                                ontologyTermName  \
# 58                    Type II diabetes mellitus
# 154    Attention deficit hyperactivity disorder
# 220                                      Asthma
# 221                                Hypertension
# 355                                Hypertension
# ...                                         ...
# 27189                                  Migraine
# 27209                              Hypertension
# 27445                              Depressivity
# 27491                          Breast carcinoma
# 28332                             Hyperuricemia
#
#                                  ontologyTermIRI  validated  review  \
# 58     http://purl.obolibrary.org/obo/HP_0005978      False   False
# 154    http://purl.obolibrary.org/obo/HP_0007018      False   False
# 220    http://purl.obolibrary.org/obo/HP_0002099      False   False
# 221    http://purl.obolibrary.org/obo/HP_0000822      False   False
# 355    http://purl.obolibrary.org/obo/HP_0000822      False   False
# ...                                          ...        ...     ...
# 27189  http://purl.obolibrary.org/obo/HP_0002076      False   False
# 27209  http://purl.obolibrary.org/obo/HP_0000822      False   False
# 27445  http://purl.obolibrary.org/obo/HP_0000716      False   False
# 27491  http://purl.obolibrary.org/obo/HP_0003002      False   False
# 28332  http://purl.obolibrary.org/obo/HP_0002149      False   False
#
#                ID
# 58     HP:0005978
# 154    HP:0007018
# 220    HP:0002099
# 221    HP:0000822
# 355    HP:0000822
# ...           ...
# 27189  HP:0002076
# 27209  HP:0000822
# 27445  HP:0000716
# 27491  HP:0003002
# 28332  HP:0002149
#
# [599 rows x 10 columns]

# %%
final_filtered.to_csv('drug_to_disease_final_v2.csv', encoding = 'utf-8-sig')
